# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import make_pipeline
from sklearn import svm, linear_model
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_curve, auc,f1_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from collections import defaultdict
import unicodedata
import random
random.seed(37)
import gensim
from gensim.models import Word2Vec
from annoy import AnnoyIndex

# %%
pd.set_option('display.max_colwidth', -1)

# %%
path = "/home/akash/projects/data_analysis/ing/data/"

# %%
companies = pd.read_csv(path+"G.csv", delimiter="|")
train = pd.read_csv(path+"STrain.csv", delimiter="|")

# %%
companies.head()
# Out:
#    company_id                        name
# 0  634022      PRIMCOM SA
# 1  324497      The David Isaacs Fund
# 2  280848      Bramor Enterprises Limited
# 3  432662      NAVEXIM S.A.
# 4  524224      Magal Group SA

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450256 entries, 0 to 450255
# Data columns (total 2 columns):
# company_id    450256 non-null int64
# name          450256 non-null object
# dtypes: int64(1), object(1)
# memory usage: 6.9+ MB

# %%
train.head()
# Out:
#    train_index                                                          name  \
# 0  0            TRATTAMENTO Ltd RIFIUTI METROPOLITANI SPA  SIGLABILE TRM SPA
# 1  1            A IRL Fuund
# 2  2            BMR-500 Kendall LLC 1 Mezz GmbH
# 3  3            Solich GmbH KG
# 4  4            Drzyzzga Funds Logi. sp. z oo
#
#    company_id
# 0  177358
# 1  568472
# 2  195692
# 3 -1
# 4  404178

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
# train_index    100000 non-null int64
# name           100000 non-null object
# company_id     100000 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 2.3+ MB

# %%
test = pd.read_csv(path+"STest.csv", delimiter=",")
test.head()
# Out:
#    test_index                                        name
# 0  0           THEking'S ROYAL HUSSARS OFFI. TRUST' TRUST
# 1  1           Southern Powe rcompany SICAV
# 2  2           BMO S&P/TSX Ladde. Share ETF Index
# 3  3           PaI
# 4  4           Clearview Two

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 2 columns):
# test_index    100000 non-null int64
# name          99999 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
print train.columns
print test.columns
# Out:
# Index([u'train_index', u'name', u'company_id'], dtype='object')
# Index([u'test_index', u'name'], dtype='object')

# %%
print train.shape
print train["name"].nunique()
# Out:
# (100000, 3)
# 99365

# %%
print test.shape
print test["name"].nunique()
# Out:
# (100000, 2)
# 99323

# %%
print len(set(test["name"]) & set(train["name"]))
# Out:
# 1075

# %%
companies = companies.reset_index(drop=True)
companies.head()
# Out:
#    company_id                        name
# 0  634022      PRIMCOM SA
# 1  324497      The David Isaacs Fund
# 2  280848      Bramor Enterprises Limited
# 3  432662      NAVEXIM S.A.
# 4  524224      Magal Group SA

# %% [markdown]
# #### Sample Data

# %%
# orig_size = len(companies)
# sample_size = 200000 
# companies = companies.sample(sample_size)

# %%
# train_0 = train.loc[train["company_id"]==-1]
# print train_0.shape

# train_1 = train.loc[train["company_id"]>=0]
# print train_1.shape

# %%
# train = train_1.loc[train_1["company_id"].isin(companies["company_id"])]
# print train.shape

# %%
# train0_sample = train_0.sample(int(sample_size/float(orig_size)*len(train_0)))
# print len(train0_sample)

# %%
# train = pd.concat([train,train0_sample])

# %%
train.shape
# Out:
# (100000, 3)

# %%
train = train.reset_index(drop=True)
train.head()
# Out:
#    train_index                                                          name  \
# 0  0            TRATTAMENTO Ltd RIFIUTI METROPOLITANI SPA  SIGLABILE TRM SPA
# 1  1            A IRL Fuund
# 2  2            BMR-500 Kendall LLC 1 Mezz GmbH
# 3  3            Solich GmbH KG
# 4  4            Drzyzzga Funds Logi. sp. z oo
#
#    company_id
# 0  177358
# 1  568472
# 2  195692
# 3 -1
# 4  404178

# %% [markdown]
# #### Make map of company_ids to Annoy_index_ids

# %%
# annoy_ids are from 0 to len(company_ids) -1 
# annoy_ids are stored in list. List index are annoy_ids and the value is teh correspodnign company_id
# Company_ids are stored in a dict. The key is company id and the value is annoy_id
def build_company_annoy_maps(company_ids):
    annoy2company = []
    company2annoy = defaultdict(lambda:0)
    for c_id in company_ids:
        if c_id not in company2annoy:
            annoy2company.append(c_id)
            company2annoy[c_id] = len(annoy2company)-1
    return annoy2company, company2annoy

# %%
annoy2company, company2annoy = build_company_annoy_maps(companies["company_id"].values)

# %%
print len(annoy2company)
print len(company2annoy)
# Out:
# 450256
# 450256

# %%
import random
for i in range(5):
    annoy_id = random.randint(0,50000)
    assert annoy_id ==  company2annoy[annoy2company[annoy_id]]
    print annoy_id, annoy2company[annoy_id], company2annoy[annoy2company[annoy_id]]
# Out:
# 34100 198710 34100
# 4580 484544 4580
# 30891 320028 30891
# 42096 89805 42096
# 41728 232717 41728

# %%
def remove_accents(df,**kw_args):
    old_col =  kw_args["old_col"]
    new_col =  kw_args["new_col"]
    def remove_accents_inner(input_str):
        nfkd_form = unicodedata.normalize('NFKD', unicode(input_str, 'utf8'))
        return u"".join([c for c in nfkd_form if not unicodedata.combining(c)])
    
    df[new_col] = df[old_col].apply(remove_accents_inner)
    return df

def make_accent_transformer(old_col, new_col):
    return FunctionTransformer(remove_accents, validate=False,
                                         kw_args={"old_col":old_col,"new_col":new_col})

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/akash/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]|@,;\-\\\+#~!$%^]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z ]')
STOPWORDS = set(stopwords.words('english'))
#-#+_!`~\\

# %%
s = "for from india and add+g-ddc.b.g,c\g-hh ak|ash#sin/gh dee$pt^a su%d"
s=re.sub(REPLACE_BY_SPACE_RE," ",s)
s= re.sub(BAD_SYMBOLS_RE,"",s)
s= ' '.join(word for word in s.split() if word not in STOPWORDS)
print s
# Out:
# india add g ddcbg c g hh ak ash sin gh dee pt su

# %%
def clean_name(df,**kw_args):
    old_col =  kw_args["old_col"]
    new_col =  kw_args["new_col"]
    
    def regex_clean(text):
        text = re.sub(REPLACE_BY_SPACE_RE, " ", text)
        text = re.sub(BAD_SYMBOLS_RE, "", text)
#         #add shorthand
#         longhand = ' '.join(word for word in text.split() if not any(c.isdigit() for c in word))
#         shorthand = "".join(word[0] for word in re.findall("\w+", longhand))
#         text = text+" "+shorthand
        return text
    
    df[new_col] = df[old_col].str.lower().str.strip()
    df[new_col] = df[old_col].apply(regex_clean)
    
    return df

def make_clean_name_transformer(old_col, new_col):
    return FunctionTransformer(clean_name, validate=False, kw_args={"old_col":old_col,"new_col":new_col})

# %%
name_pipeline = make_pipeline(make_accent_transformer("name", "clean_name"),
                                    make_clean_name_transformer("clean_name", "clean_name"))
companies = name_pipeline.transform(companies)

# %%
companies.sample(10)
# Out:
#         company_id                                name  \
# 72291   245672      Redwood Capital Bank
# 46731   547523      W.J. Thijn Stichting
# 174399  283043      Washington Gardens Plantation, LLC
# 98868   379243      GENEDRIVE PLC
# 301109  543762      PYME VALENCIA 1 FTA
# 93697   537995      LEXELL
# 205431  32903       TEHATTA HOLDINGS LIMITED
# 416788  409946      Petersen Bros., Inc.
# 307423  446826      Aarslev Skovgård/Laust Bie
# 346428  412894      DISMAG
#
#                                 clean_name
# 72291   redwood capital bank
# 46731   wj thijn stichting
# 174399  washington gardens plantation  llc
# 98868   genedrive plc
# 301109  pyme valencia 1 fta
# 93697   lexell
# 205431  tehatta holdings limited
# 416788  petersen bros  inc
# 307423  aarslev skovgard laust bie
# 346428  dismag

# %%
print companies.shape
print companies["clean_name"].nunique()
# Out:
# (450256, 3)
# 448231

# %%
train.head()
# Out:
#    train_index                                                          name  \
# 0  0            TRATTAMENTO Ltd RIFIUTI METROPOLITANI SPA  SIGLABILE TRM SPA
# 1  1            A IRL Fuund
# 2  2            BMR-500 Kendall LLC 1 Mezz GmbH
# 3  3            Solich GmbH KG
# 4  4            Drzyzzga Funds Logi. sp. z oo
#
#    company_id
# 0  177358
# 1  568472
# 2  195692
# 3 -1
# 4  404178

# %%
print train.shape
train.sample(10)
# Out:
# (100000, 3)
#        train_index  \
# 57053  57053
# 50544  50544
# 72321  72321
# 75318  75318
# 87871  87871
# 10321  10321
# 810    810
# 16725  16725
# 60269  60269
# 65646  65646
#
#                                                                   name  \
# 57053  NNL
# 50544  Sarak Fastigheter AB
# 72321  Providence TMT Special Fundsituations L.P.
# 75318  Focus UAB
# 87871  "uBASF POLSKA" SPÓŁKA Z ODPO.
# 10321  CFORA METAL Global
# 810    MetLifereinsurance Carolina of South Inc Company
# 16725  UNIV., THE CMI GLOBAL NETWORK FUND - CMI GERMAN EQUITY SUB-FUND
# 60269  POWSZ. TOWA RZYSTWOinwestycyjne S.A.
# 65646  Cnnell Bros. CHKL International
#
#        company_id
# 57053  608558
# 50544  533371
# 72321 -1
# 75318  167145
# 87871  484642
# 10321  567081
# 810    461217
# 16725  533991
# 60269  442384
# 65646  320341

# %%
from collections import Counter
count_vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 1), min_df=1)
# X matrix where the row represents sentences and column is our one-hot vector for each token in our vocabulary
X = count_vectorizer.fit_transform(companies["clean_name"])

# Vocabulary
vocab = list(count_vectorizer.get_feature_names())

# Column-wise sum of the X matrix.
# It's some crazy numpy syntax that looks horribly unpythonic
# For details, see http://stackoverflow.com/questions/3337301/numpy-matrix-to-array
# and http://stackoverflow.com/questions/13567345/how-to-calculate-the-sum-of-all-columns-of-a-2d-numpy-array-efficiently
counts = X.sum(axis=0).A1

freq_distribution = Counter(dict(zip(vocab, counts)))

# %%
print (freq_distribution.most_common(100))
# Out:
# [(u'llc', 44288), (u'fund', 38551), (u'limited', 34803), (u'gmbh', 29272), (u'inc', 24952), (u'bv', 21019), (u'srl', 20646), (u'trust', 20440), (u'ltd', 16548), (u'sa', 15202), (u'co', 12984), (u'lp', 11681), (u'global', 11272), (u'de', 10292), (u'the', 10220), (u'company', 10159), (u'funds', 9906), (u'kg', 9865), (u'holding', 9770), (u'ab', 9459), (u'investment', 8335), (u'sl', 7666), (u'capital', 7485), (u'international', 7283), (u'equity', 6886), (u'di', 6700), (u'holdings', 6683), (u'of', 6680), (u'spa', 6663), (u'group', 6212), (u'as', 6092), (u'ii', 6061), (u'sicav', 5883), (u'management', 5723), (u'investments', 5456), (u'aps', 5192), (u'portfolio', 4959), (u'bond', 4854), (u'partners', 4848), (u'societa', 4605), (u'invest', 4526), (u'and', 4211), (u'oy', 4152), (u'sro', 4143), (u'bank', 3981), (u'plc', 3861), (u'services', 3851), (u'income', 3848), (u'master', 3799), (u'corporation', 3747), (u'nv', 3573), (u'beheer', 3568), (u'mbh', 3509), (u'spoka', 3506), (u'ag', 3479), (u'settlement', 3331), (u'series', 3274), (u'asset', 3227), (u'etf', 3223), (u'fonds', 3183), (u'europe', 3182), (u'credit', 3158), (u'us', 3081), (u'und', 3062), (u'uk', 3029), (u'properties', 3014), (u'sp', 2970), (u'sas', 2925), (u'in', 2895), (u'index', 2853), (u'energy', 2847), (u'street', 2815), (u'finance', 2742), (u'snc', 2719), (u'real', 2631), (u'public', 2604), (u'markets', 2541), (u'rl', 2510), (u'aktiebolag', 2493), (u'pty', 2451), (u'emerging', 2417), (u'van', 2403), (u'multi', 2368), (u'trading', 2365), (u'iii', 2326), (u'growth', 2325), (u'estate', 2320), (u'tarsasag', 2298), (u'solutions', 2260), (u'korlatolt', 2237), (u'partnership', 2233), (u'felelossegu', 2225), (u'pension', 2175), (u'euro', 2142), (u'opportunities', 2138), (u'oo', 2129), (u'ograniczona', 2127), (u'odpowiedzialnoscia', 2116), (u'for', 2112), (u'property', 2076)]

# %%
train = name_pipeline.transform(train)

# %%
train.sample(10)
# Out:
#        train_index                                      name  company_id  \
# 75813  75813        ABERDEEN PRIVATE EQUITY MANAGERS LIMITED  614554
# 87288  87288        INVERNIZZI LUCIANO & FvIGLI S.P.A.        600698
# 9251   9251         Stahlgruber Ottog. AG                    -1
# 22655  22655        GAoERIE ENRICO NAVARRA                   -1
# 9301   9301         VCI                                       188349
# 24876  24876        DAS AHUS S.R.L.                           436081
# 88339  88339        MI-FONDS F95                              138767
# 96882  96882        Aretea Special Inc Marit imeenterprise   -1
# 49862  49862        Cb Holding ApS Hanstholm                 -1
# 98963  98963        2020, L.C.                                382712
#
#                                      clean_name
# 75813  aberdeen private equity managers limited
# 87288  invernizzi luciano  fvigli spa
# 9251   stahlgruber ottog ag
# 22655  gaoerie enrico navarra
# 9301   vci
# 24876  das ahus srl
# 88339  mi fonds f95
# 96882  aretea special inc marit imeenterprise
# 49862  cb holding aps hanstholm
# 98963  2020  lc

# %%
import gensim
assert gensim.models.doc2vec.FAST_VERSION > -1

# %%
companies.head(10)
# Out:
#    company_id                                                   name  \
# 0  634022      PRIMCOM SA
# 1  324497      The David Isaacs Fund
# 2  280848      Bramor Enterprises Limited
# 3  432662      NAVEXIM S.A.
# 4  524224      Magal Group SA
# 5  513585      Marly SPF S.A.
# 6  354496      I.T APPARELS LIMITED
# 7  381944      VX 30.141 ApS
# 8  526057      Rydex ETF Trust - Guggenheim S&P 500 Equal Weight ETF
# 9  34381       Rydex Series Funds - Retailing Fund
#
#                                              clean_name
# 0  primcom sa
# 1  the david isaacs fund
# 2  bramor enterprises limited
# 3  navexim sa
# 4  magal group sa
# 5  marly spf sa
# 6  it apparels limited
# 7  vx 30141 aps
# 8  rydex etf trust   guggenheim sp 500 equal weight etf
# 9  rydex series funds   retailing fund

# %%
b='student ddg dfs'
n=4
print [b[i:i+n] for i in range(len(b)-n+1)]
# Out:
# ['stud', 'tude', 'uden', 'dent', 'ent ', 'nt d', 't dd', ' ddg', 'ddg ', 'dg d', 'g df', ' dfs']

# %% [markdown]
# #### SETTINGS

# %%
n_grams=[2,3]
dim =400
window =5
min_count=5
workers=4
num_trees_annoy=300

# %%
def make_corpus(names, n_grams= [3]):
    corpus = []
    for name in names:
        name_grams = []
        for n in n_grams:
            name_grams.extend([name[i:i+n] for i in range(len(name)-n+1)])
        corpus.append(name_grams)
    return corpus

# %%
def make_name_vectors(corpus):
    name_vectors = np.empty(shape=(len(corpus),dim))
    for idx, name in enumerate(corpus):
        name_vector = name_to_vec(name, model.wv)
        name_vectors[idx,:] = name_vector
    return name_vectors

# %%
def name_to_vec(name, embeddings, dim=dim):
    """
        name: a string
        embeddings: dict where the key is a word and a value is its' embedding
        dim: size of the representation

        result: vector representation for the question
    """
    
    result = np.zeros(shape=dim)
    count = 0
    for word in name:
        if word in embeddings:
            result = result + embeddings[word]
            count+=1
    
    if count>0:
        result = result/count
        
    return result

# %%
company_corpus = make_corpus(companies["clean_name"], n_grams)

# %%
len(company_corpus)
# Out:
# 450256

# %%
companies.head()
# Out:
#    company_id                        name                  clean_name
# 0  634022      PRIMCOM SA                  primcom sa
# 1  324497      The David Isaacs Fund       the david isaacs fund
# 2  280848      Bramor Enterprises Limited  bramor enterprises limited
# 3  432662      NAVEXIM S.A.                navexim sa
# 4  524224      Magal Group SA              magal group sa

# %%
company_corpus[0:5]
# Out:
# [[u'pr',
#   u'ri',
#   u'im',
#   u'mc',
#   u'co',
#   u'om',
#   u'm ',
#   u' s',
#   u'sa',
#   u'pri',
#   u'rim',
#   u'imc',
#   u'mco',
#   u'com',
#   u'om ',
#   u'm s',
#   u' sa'],
#  [u'th',
#   u'he',
#   u'e ',
#   u' d',
#   u'da',
#   u'av',
#   u'vi',
#   u'id',
#   u'd ',
#   u' i',
#   u'is',
#   u'sa',
#   u'aa',
#   u'ac',
#   u'cs',
#   u's ',
#   u' f',
#   u'fu',
#   u'un',
#   u'nd',
#   u'the',
#   u'he ',
#   u'e d',
#   u' da',
#   u'dav',
#   u'avi',
#   u'vid',
#   u'id ',
#   u'd i',
#   u' is',
#   u'isa',
#   u'saa',
#   u'aac',
#   u'acs',
#   u'cs ',
#   u's f',
#   u' fu',
#   u'fun',
#   u'und'],
#  [u'br',
#   u'ra',
#   u'am',
#   u'mo',
#   u'or',
#   u'r ',
#   u' e',
#   u'en',
#   u'nt',
#   u'te',
#   u'er',
#   u'rp',
#   u'pr',
#   u'ri',
#   u'is',
#   u'se',
#   u'es',
#   u's ',
#   u' l',
#   u'li',
#   u'im',
#   u'mi',
#   u'it',
#   u'te',
#   u'ed',
#   u'bra',
#   u'ram',
#   u'amo',
#   u'mor',
#   u'or ',
#   u'r e',
#   u' en',
#   u'ent',
#   u'nte',
#   u'ter',
#   u'erp',
#   u'rpr',
#   u'pri',
#   u'ris',
#   u'ise',
#   u'ses',
#   u'es ',
#   u's l',
#   u' li',
#   u'lim',
#   u'imi',
#   u'mit',
#   u'ite',
#   u'ted'],
#  [u'na',
#   u'av',
#   u've',
#   u'ex',
#   u'xi',
#   u'im',
#   u'm ',
#   u' s',
#   u'sa',
#   u'nav',
#   u'ave',
#   u'vex',
#   u'exi',
#   u'xim',
#   u'im ',
#   u'm s',
#   u' sa'],
#  [u'ma',
#   u'ag',
#   u'ga',
#   u'al',
#   u'l ',
#   u' g',
#   u'gr',
#   u'ro',
#   u'ou',
#   u'up',
#   u'p ',
#   u' s',
#   u'sa',
#   u'mag',
#   u'aga',
#   u'gal',
#   u'al ',
#   u'l g',
#   u' gr',
#   u'gro',
#   u'rou',
#   u'oup',
#   u'up ',
#   u'p s',
#   u' sa']]

# %%
print gensim.models.doc2vec.FAST_VERSION
# Out:
# 1

# %%
model = Word2Vec(company_corpus, size=dim, window=window, min_count=min_count, workers=workers)
model.wv

# %%
model.wv

# %%
model.wv["llc"].size
# Out:
# 300

# %%
company_vectors = make_name_vectors(company_corpus)

# %%
company_vectors[0:5]
# Out:
# array([[ 0.29744164, -0.31892795,  0.02504915, ..., -0.02284963,
#         -0.33021586,  0.03254006],
#        [ 0.00308102,  0.14935247,  0.31973143, ...,  0.22377759,
#         -0.34552417,  0.21090331],
#        [ 0.3201684 ,  0.43908448,  0.23285988, ..., -0.02601147,
#         -0.35725095, -0.01262979],
#        [-0.05307632,  0.14373445,  0.30242449, ..., -0.41301112,
#         -0.2799158 ,  0.17310317],
#        [ 0.54007183,  0.09744463,  0.20262157, ..., -0.08723755,
#         -0.10712737, -0.54897497]])

# %%
index_size = dim
table = AnnoyIndex(index_size)

for i in range(company_vectors.shape[0]):
    if i%20000==0:
        print "indexed %s items"%i
    table.add_item(i,company_vectors[i])
# Out:
# indexed 0 items
# indexed 20000 items
# indexed 40000 items
# indexed 60000 items
# indexed 80000 items
# indexed 100000 items
# indexed 120000 items
# indexed 140000 items
# indexed 160000 items
# indexed 180000 items
# indexed 200000 items
# indexed 220000 items
# indexed 240000 items
# indexed 260000 items
# indexed 280000 items
# indexed 300000 items
# indexed 320000 items
# indexed 340000 items
# indexed 360000 items
# indexed 380000 items
# indexed 400000 items
# indexed 420000 items
# indexed 440000 items

# %%
table.build(num_trees_annoy)
# Out:
# True

# %%
table.save("annoy_w2vec_index.ann")
# Out:
# True

# %%
table = AnnoyIndex(index_size)
table.load("annoy_w2vec_index.ann")
# Out:
# True

# %% [markdown]
# #### Reteiveal

# %%
train = train.merge(companies, how="left", on="company_id", suffixes=('','_truth'))

# %%
train.head()
# Out:
#    train_index                                                          name  \
# 0  0            TRATTAMENTO Ltd RIFIUTI METROPOLITANI SPA  SIGLABILE TRM SPA
# 1  1            A IRL Fuund
# 2  2            BMR-500 Kendall LLC 1 Mezz GmbH
# 3  3            Solich GmbH KG
# 4  4            Drzyzzga Funds Logi. sp. z oo
#
#    company_id                                                    clean_name  \
# 0  177358      trattamento ltd rifiuti metropolitani spa  siglabile trm spa
# 1  568472      a irl fuund
# 2  195692      bmr 500 kendall llc 1 mezz gmbh
# 3 -1           solich gmbh kg
# 4  404178      drzyzzga funds logi sp z oo
#
#                                                       name_truth  \
# 0  TRATTAMENTO RIFIUTI METROPOLITANI S.P.A. SIGLABILE TRM S.P.A.
# 1  ITALIAN CREDIT SOCIETA' A RESPONSABILITA' LIMITATA
# 2  BRE-BMR-500 Kendall Mezz 1 LLC
# 3  NaN
# 4  Drzyzga Logistics Group sp. z o.o.
#
#                                           clean_name_truth
# 0  trattamento rifiuti metropolitani spa siglabile trm spa
# 1  italian credit societa a responsabilita limitata
# 2  bre bmr 500 kendall mezz 1 llc
# 3  NaN
# 4  drzyzga logistics group sp z oo

# %%
train_corpus = make_corpus(train["clean_name"], n_grams)

# %%
train_corpus[0:5]
# Out:
# [[u'tr',
#   u'ra',
#   u'at',
#   u'tt',
#   u'ta',
#   u'am',
#   u'me',
#   u'en',
#   u'nt',
#   u'to',
#   u'o ',
#   u' l',
#   u'lt',
#   u'td',
#   u'd ',
#   u' r',
#   u'ri',
#   u'if',
#   u'fi',
#   u'iu',
#   u'ut',
#   u'ti',
#   u'i ',
#   u' m',
#   u'me',
#   u'et',
#   u'tr',
#   u'ro',
#   u'op',
#   u'po',
#   u'ol',
#   u'li',
#   u'it',
#   u'ta',
#   u'an',
#   u'ni',
#   u'i ',
#   u' s',
#   u'sp',
#   u'pa',
#   u'a ',
#   u'  ',
#   u' s',
#   u'si',
#   u'ig',
#   u'gl',
#   u'la',
#   u'ab',
#   u'bi',
#   u'il',
#   u'le',
#   u'e ',
#   u' t',
#   u'tr',
#   u'rm',
#   u'm ',
#   u' s',
#   u'sp',
#   u'pa',
#   u'tra',
#   u'rat',
#   u'att',
#   u'tta',
#   u'tam',
#   u'ame',
#   u'men',
#   u'ent',
#   u'nto',
#   u'to ',
#   u'o l',
#   u' lt',
#   u'ltd',
#   u'td ',
#   u'd r',
#   u' ri',
#   u'rif',
#   u'ifi',
#   u'fiu',
#   u'iut',
#   u'uti',
#   u'ti ',
#   u'i m',
#   u' me',
#   u'met',
#   u'etr',
#   u'tro',
#   u'rop',
#   u'opo',
#   u'pol',
#   u'oli',
#   u'lit',
#   u'ita',
#   u'tan',
#   u'ani',
#   u'ni ',
#   u'i s',
#   u' sp',
#   u'spa',
#   u'pa ',
#   u'a  ',
#   u'  s',
#   u' si',
#   u'sig',
#   u'igl',
#   u'gla',
#   u'lab',
#   u'abi',
#   u'bil',
#   u'ile',
#   u'le ',
#   u'e t',
#   u' tr',
#   u'trm',
#   u'rm ',
#   u'm s',
#   u' sp',
#   u'spa'],
#  [u'a ',
#   u' i',
#   u'ir',
#   u'rl',
#   u'l ',
#   u' f',
#   u'fu',
#   u'uu',
#   u'un',
#   u'nd',
#   u'a i',
#   u' ir',
#   u'irl',
#   u'rl ',
#   u'l f',
#   u' fu',
#   u'fuu',
#   u'uun',
#   u'und'],
#  [u'bm',
#   u'mr',
#   u'r ',
#   u' 5',
#   u'50',
#   u'00',
#   u'0 ',
#   u' k',
#   u'ke',
#   u'en',
#   u'nd',
#   u'da',
#   u'al',
#   u'll',
#   u'l ',
#   u' l',
#   u'll',
#   u'lc',
#   u'c ',
#   u' 1',
#   u'1 ',
#   u' m',
#   u'me',
#   u'ez',
#   u'zz',
#   u'z ',
#   u' g',
#   u'gm',
#   u'mb',
#   u'bh',
#   u'bmr',
#   u'mr ',
#   u'r 5',
#   u' 50',
#   u'500',
#   u'00 ',
#   u'0 k',
#   u' ke',
#   u'ken',
#   u'end',
#   u'nda',
#   u'dal',
#   u'all',
#   u'll ',
#   u'l l',
#   u' ll',
#   u'llc',
#   u'lc ',
#   u'c 1',
#   u' 1 ',
#   u'1 m',
#   u' me',
#   u'mez',
#   u'ezz',
#   u'zz ',
#   u'z g',
#   u' gm',
#   u'gmb',
#   u'mbh'],
#  [u'so',
#   u'ol',
#   u'li',
#   u'ic',
#   u'ch',
#   u'h ',
#   u' g',
#   u'gm',
#   u'mb',
#   u'bh',
#   u'h ',
#   u' k',
#   u'kg',
#   u'sol',
#   u'oli',
#   u'lic',
#   u'ich',
#   u'ch ',
#   u'h g',
#   u' gm',
#   u'gmb',
#   u'mbh',
#   u'bh ',
#   u'h k',
#   u' kg'],
#  [u'dr',
#   u'rz',
#   u'zy',
#   u'yz',
#   u'zz',
#   u'zg',
#   u'ga',
#   u'a ',
#   u' f',
#   u'fu',
#   u'un',
#   u'nd',
#   u'ds',
#   u's ',
#   u' l',
#   u'lo',
#   u'og',
#   u'gi',
#   u'i ',
#   u' s',
#   u'sp',
#   u'p ',
#   u' z',
#   u'z ',
#   u' o',
#   u'oo',
#   u'drz',
#   u'rzy',
#   u'zyz',
#   u'yzz',
#   u'zzg',
#   u'zga',
#   u'ga ',
#   u'a f',
#   u' fu',
#   u'fun',
#   u'und',
#   u'nds',
#   u'ds ',
#   u's l',
#   u' lo',
#   u'log',
#   u'ogi',
#   u'gi ',
#   u'i s',
#   u' sp',
#   u'sp ',
#   u'p z',
#   u' z ',
#   u'z o',
#   u' oo']]

# %%
#train_vectors = tfidf_vectorizer.transform(train["clean_name"])
train_vectors = make_name_vectors(train_corpus)

# %%
train_vectors[0:5]
# Out:
# array([[ 0.31575099,  0.30591132, -0.14162671, ..., -0.34862647,
#         -0.31480219, -0.05502205],
#        [ 0.69992434, -0.04381567,  0.0968002 , ...,  0.25603873,
#          0.02132178,  0.65427645],
#        [-0.40363997,  0.10854598, -0.08780978, ...,  0.13526529,
#         -0.21051361,  0.29527278],
#        [-0.02022164,  0.4876231 ,  0.2092411 , ...,  0.58622823,
#         -0.1294124 ,  0.46231079],
#        [-0.05229993,  0.33571559, -0.02351667, ...,  0.38758845,
#          0.16435868,  0.27660724]])

# %%
def get_nearest_neighbours(vectors, num_neighbours=1, search_nodes=-1, include_distances=True):
    neighbours = np.empty(shape=(len(vectors),num_neighbours), dtype=np.int32)
    distances = np.empty(shape=(len(vectors),num_neighbours))
#     print len(vectors)
#     print neighbours.shape
#     print distances.shape
    for idx,v in enumerate(vectors):
        annoy_ids, annoy_distances = table.get_nns_by_vector(v, n=num_neighbours, search_k=search_nodes, include_distances=include_distances)
        neighbours[idx,:] = annoy_ids
        distances[idx,:] = annoy_distances
    return neighbours, distances

# %%
neighbours, distances = get_nearest_neighbours(train_vectors)

# %%
neigbours =np.vectorize(lambda x: annoy2company[x])(neighbours)

# %%
rank_1 = neigbours[:,0]
rank_1
# Out:
# array([177358,  24825, 195692, ..., 377115, 192951, 386428])

# %%
train["rank1_id"] = rank_1

# %%
train= train.merge(companies[['company_id', 'clean_name']], left_on="rank1_id", 
                   right_on="company_id", suffixes=("","_rank1"))

# %%
train
# Out:
#        train_index  \
# 0      0
# 1      1
# 2      2347
# 3      5361
# 4      16823
# 5      17491
# 6      17525
# 7      23518
# 8      25932
# 9      35389
# 10     35686
# 11     37939
# 12     38544
# 13     40095
# 14     44122
# 15     47232
# 16     50430
# 17     52599
# 18     56609
# 19     71377
# 20     73626
# 21     73944
# 22     75273
# 23     79509
# 24     79511
# 25     93341
# 26     94973
# 27     98784
# 28     2
# 29     3
# ...   ..
# 99970  99952
# 99971  99953
# 99972  99956
# 99973  99957
# 99974  99959
# 99975  99960
# 99976  99961
# 99977  99962
# 99978  99963
# 99979  99964
# 99980  99966
# 99981  99967
# 99982  99970
# 99983  99972
# 99984  99973
# 99985  99974
# 99986  99975
# 99987  99977
# 99988  99980
# 99989  99981
# 99990  99982
# 99991  99984
# 99992  99986
# 99993  99987
# 99994  99988
# 99995  99989
# 99996  99990
# 99997  99991
# 99998  99994
# 99999  99997
#
#                                                                                                name  \
# 0      TRATTAMENTO Ltd RIFIUTI METROPOLITANI SPA  SIGLABILE TRM SPA
# 1      A IRL Fuund
# 2      PS2A Fund
# 3      IHL FUND.
# 4      BNL FUND
# 5      YTL Fund
# 6      X STL Fund
# 7      a HaTB FUND
# 8      SAL Fund
# 9      hMGA FUND
# 10     AHE Fund
# 11     AIFL FUND
# 12     S8L Fund
# 13     AOHL Fund
# 14     APL FUND
# 15     AKG Fund
# 16     AR Fund
# 17     NSA Fund
# 18     ATL Fund
# 19     TECA Funds Fund
# 20     MBDA Fund
# 21     TPL FUND.
# 22     RVL Fund
# 23     ML Fund
# 24     GLA FUND.
# 25     JFSA Fund
# 26     FQA FUND
# 27     RuA GmH FUND
# 28     BMR-500 Kendall LLC 1 Mezz GmbH
# 29     Solich GmbH KG
# ...               ...
# 99970  Lesir kka Oy
# 99971  MUTU ELLE JUST
# 99972  GILLIAN MANNgrandchildren'S TRUST Ltd
# 99973  ORTEX , spol. s ro
# 99974  CALYPSO TAUX
# 99975  Conn. CI AB
# 99976  GIBALS TRUST
# 99977  HANAMI
# 99978  Natixis International Funds (Lux) I - Loomis Sayles Institutional Global Corporate Bond Fund
# 99979  Volksbank Meer. eG
# 99980  WS JENKINS PENSION SCHEME
# 99981  Dimerco Express (Canada) Corporation
# 99982  Abacus MFP IV LP
# 99983  GBSON'S CHARITY
# 99984  Aktie. Skövdebostäder
# 99985  Administradora de Consorcio RCI Equity Brasil Ltda
# 99986  VermogensParapluFonds - RAM Emerg.
# 99987  DPV S.P.A.
# 99988  Jmd igyn SC SPRL
# 99989  GM Holdigs U.K. No. 1 Limited
# 99990  Cherry Cent ralcooperative, Inc.
# 99991  JJ Oxford, L.L.C.
# 99992  ZANNINI Litd - SPA
# 99993  uLmi rama Inc.
# 99994  ANATRAC Capital A & I SA
# 99995  Roermondse Stic. 1880
# 99996  Morningstar Shares International igh Opportunities (Hedged) Fund
# 99997  C.C.M. Steur Pensioen B.V.
# 99998  ANH B.V.
# 99999  GRUPO ANTOLIN IRAUSA S.A.
#
#        company_id  \
# 0      177358
# 1      568472
# 2     -1
# 3     -1
# 4      560940
# 5      438121
# 6      516763
# 7     -1
# 8      466656
# 9      632543
# 10    -1
# 11     402880
# 12     252386
# 13     566651
# 14     66244
# 15     531867
# 16    -1
# 17     62205
# 18    -1
# 19     479551
# 20     294356
# 21     522645
# 22    -1
# 23    -1
# 24     247117
# 25     217750
# 26     24825
# 27     131964
# 28     195692
# 29    -1
# ...   ..
# 99970  577991
# 99971  557517
# 99972 -1
# 99973  115370
# 99974 -1
# 99975  577077
# 99976  42225
# 99977 -1
# 99978  269580
# 99979 -1
# 99980  49128
# 99981  72130
# 99982 -1
# 99983  462657
# 99984  395359
# 99985  566768
# 99986  315690
# 99987  91735
# 99988 -1
# 99989  68844
# 99990  615294
# 99991  631711
# 99992  226393
# 99993  507886
# 99994  511966
# 99995 -1
# 99996  65798
# 99997 -1
# 99998  50400
# 99999 -1
#
#                                                                                          clean_name  \
# 0      trattamento ltd rifiuti metropolitani spa  siglabile trm spa
# 1      a irl fuund
# 2      ps2a fund
# 3      ihl fund
# 4      bnl fund
# 5      ytl fund
# 6      x stl fund
# 7      a hatb fund
# 8      sal fund
# 9      hmga fund
# 10     ahe fund
# 11     aifl fund
# 12     s8l fund
# 13     aohl fund
# 14     apl fund
# 15     akg fund
# 16     ar fund
# 17     nsa fund
# 18     atl fund
# 19     teca funds fund
# 20     mbda fund
# 21     tpl fund
# 22     rvl fund
# 23     ml fund
# 24     gla fund
# 25     jfsa fund
# 26     fqa fund
# 27     rua gmh fund
# 28     bmr 500 kendall llc 1 mezz gmbh
# 29     solich gmbh kg
# ...               ...
# 99970  lesir kka oy
# 99971  mutu elle just
# 99972  gillian manngrandchildrens trust ltd
# 99973  ortex   spol s ro
# 99974  calypso taux
# 99975  conn ci ab
# 99976  gibals trust
# 99977  hanami
# 99978  natixis international funds  lux  i   loomis sayles institutional global corporate bond fund
# 99979  volksbank meer eg
# 99980  ws jenkins pension scheme
# 99981  dimerco express  canada  corporation
# 99982  abacus mfp iv lp
# 99983  gbsons charity
# 99984  aktie skovdebostader
# 99985  administradora de consorcio rci equity brasil ltda
# 99986  vermogensparaplufonds   ram emerg
# 99987  dpv spa
# 99988  jmd igyn sc sprl
# 99989  gm holdigs uk no 1 limited
# 99990  cherry cent ralcooperative  inc
# 99991  jj oxford  llc
# 99992  zannini litd   spa
# 99993  ulmi rama inc
# 99994  anatrac capital a  i sa
# 99995  roermondse stic 1880
# 99996  morningstar shares international igh opportunities  hedged  fund
# 99997  ccm steur pensioen bv
# 99998  anh bv
# 99999  grupo antolin irausa sa
#
#                                                                                          name_truth  \
# 0      TRATTAMENTO RIFIUTI METROPOLITANI S.P.A. SIGLABILE TRM S.P.A.
# 1      ITALIAN CREDIT SOCIETA' A RESPONSABILITA' LIMITATA
# 2      NaN
# 3      NaN
# 4      LLOYDS BANK NOMINEES LIMITED
# 5      YBOR Tropical, LLC
# 6      Spire X Trading LLC
# 7      NaN
# 8      Svitzer Australia Pty Ltd
# 9      MGA
# 10     NaN
# 11     Accelerated International Forwarders, LLC
# 12     8th Street, LLC
# 13     ALLIANCE ONE HOLDINGS LIMITED
# 14     APB Properties, LLC
# 15     ABUS Kransysteme GmbH
# 16     NaN
# 17     Stichting Natura Africae
# 18     NaN
# 19     Active Europe Common Trust Fund
# 20     MBDA
# 21     TCS Property, Ltd.
# 22     NaN
# 23     NaN
# 24     Global Ascent Ltd.
# 25     JPMorgan Funds - Systematic Alpha Fund
# 26     FQA FUND
# 27     REIFF Reifen und Autotechnik GmbH
# 28     BRE-BMR-500 Kendall Mezz 1 LLC
# 29     NaN
# ...    ...
# 99970  Lesirkka Oy
# 99971  MUTUELLE JUST
# 99972  NaN
# 99973  ORTEX , spol. s r.o.
# 99974  NaN
# 99975  Connecting Capital Invest AB
# 99976  GIBLAS
# 99977  NaN
# 99978  Natixis International Funds (Lux) I - Loomis Sayles Institutional Global Corporate Bond Fund
# 99979  NaN
# 99980  WS JENKINS PENSION SCHEME
# 99981  Dimerco Express (Canada) Corporation
# 99982  NaN
# 99983  GIBSON'S CHARITY
# 99984  Aktiebolaget Skövdebostäder
# 99985  Administradora de Consorcio RCI Brasil Ltda
# 99986  VermogensParapluFonds - RAM Emerging Conservative
# 99987  DELLA PERUTA VINCENZO S.P.A.
# 99988  NaN
# 99989  GM Holdings U.K. No. 1 Limited
# 99990  Cherry Central Cooperative, Inc.
# 99991  JJ Oxford, L.L.C.
# 99992  ZANNINI - S.P.A.
# 99993  Lumirama Inc.
# 99994  ANATRAC A & I SA
# 99995  NaN
# 99996  Morningstar International Shares High Opportunities (Hedged) Fund
# 99997  NaN
# 99998  AEGON NEVAK Holding B.V.
# 99999  NaN
#
#                                                                                    clean_name_truth  \
# 0      trattamento rifiuti metropolitani spa siglabile trm spa
# 1      italian credit societa a responsabilita limitata
# 2      NaN
# 3      NaN
# 4      lloyds bank nominees limited
# 5      ybor tropical  llc
# 6      spire x trading llc
# 7      NaN
# 8      svitzer australia pty ltd
# 9      mga
# 10     NaN
# 11     accelerated international forwarders  llc
# 12     8th street  llc
# 13     alliance one holdings limited
# 14     apb properties  llc
# 15     abus kransysteme gmbh
# 16     NaN
# 17     stichting natura africae
# 18     NaN
# 19     active europe common trust fund
# 20     mbda
# 21     tcs property  ltd
# 22     NaN
# 23     NaN
# 24     global ascent ltd
# 25     jpmorgan funds   systematic alpha fund
# 26     fqa fund
# 27     reiff reifen und autotechnik gmbh
# 28     bre bmr 500 kendall mezz 1 llc
# 29     NaN
# ...    ...
# 99970  lesirkka oy
# 99971  mutuelle just
# 99972  NaN
# 99973  ortex   spol s ro
# 99974  NaN
# 99975  connecting capital invest ab
# 99976  giblas
# 99977  NaN
# 99978  natixis international funds  lux  i   loomis sayles institutional global corporate bond fund
# 99979  NaN
# 99980  ws jenkins pension scheme
# 99981  dimerco express  canada  corporation
# 99982  NaN
# 99983  gibsons charity
# 99984  aktiebolaget skovdebostader
# 99985  administradora de consorcio rci brasil ltda
# 99986  vermogensparaplufonds   ram emerging conservative
# 99987  della peruta vincenzo spa
# 99988  NaN
# 99989  gm holdings uk no 1 limited
# 99990  cherry central cooperative  inc
# 99991  jj oxford  llc
# 99992  zannini   spa
# 99993  lumirama inc
# 99994  anatrac a  i sa
# 99995  NaN
# 99996  morningstar international shares high opportunities  hedged  fund
# 99997  NaN
# 99998  aegon nevak holding bv
# 99999  NaN
#
#        rank1_id  company_id_rank1  \
# 0      177358    177358
# 1      24825     24825
# 2      24825     24825
# 3      24825     24825
# 4      24825     24825
# 5      24825     24825
# 6      24825     24825
# 7      24825     24825
# 8      24825     24825
# 9      24825     24825
# 10     24825     24825
# 11     24825     24825
# 12     24825     24825
# 13     24825     24825
# 14     24825     24825
# 15     24825     24825
# 16     24825     24825
# 17     24825     24825
# 18     24825     24825
# 19     24825     24825
# 20     24825     24825
# 21     24825     24825
# 22     24825     24825
# 23     24825     24825
# 24     24825     24825
# 25     24825     24825
# 26     24825     24825
# 27     24825     24825
# 28     195692    195692
# 29     548888    548888
# ...       ...       ...
# 99970  577991    577991
# 99971  557517    557517
# 99972  440407    440407
# 99973  115370    115370
# 99974  498921    498921
# 99975  390161    390161
# 99976  267587    267587
# 99977  386954    386954
# 99978  269580    269580
# 99979  468212    468212
# 99980  49128     49128
# 99981  72130     72130
# 99982  67585     67585
# 99983  462657    462657
# 99984  204428    204428
# 99985  566768    566768
# 99986  550842    550842
# 99987  624278    624278
# 99988  458511    458511
# 99989  104577    104577
# 99990  615294    615294
# 99991  631711    631711
# 99992  226393    226393
# 99993  507886    507886
# 99994  180907    180907
# 99995  411598    411598
# 99996  65798     65798
# 99997  18638     18638
# 99998  500856    500856
# 99999  377115    377115
#
#                                                                                    clean_name_rank1
# 0      trattamento rifiuti metropolitani spa siglabile trm spa
# 1      fqa fund
# 2      fqa fund
# 3      fqa fund
# 4      fqa fund
# 5      fqa fund
# 6      fqa fund
# 7      fqa fund
# 8      fqa fund
# 9      fqa fund
# 10     fqa fund
# 11     fqa fund
# 12     fqa fund
# 13     fqa fund
# 14     fqa fund
# 15     fqa fund
# 16     fqa fund
# 17     fqa fund
# 18     fqa fund
# 19     fqa fund
# 20     fqa fund
# 21     fqa fund
# 22     fqa fund
# 23     fqa fund
# 24     fqa fund
# 25     fqa fund
# 26     fqa fund
# 27     fqa fund
# 28     bre bmr 500 kendall mezz 1 llc
# 29     h gautzsch gmbh  co kg
# ...                       ...
# 99970  lesirkka oy
# 99971  mutuelle just
# 99972  ian mcalpine grandchildrens trust
# 99973  ortex   spol s ro
# 99974  calypso
# 99975  giovanni agnelli e c societa in accomandita per azioni
# 99976  coils australia trust
# 99977  manhattan laminates ltd
# 99978  natixis international funds  lux  i   loomis sayles institutional global corporate bond fund
# 99979  volksbank jever eg
# 99980  ws jenkins pension scheme
# 99981  dimerco express  canada  corporation
# 99982  jcf aiv p lp
# 99983  gibsons charity
# 99984  orebrobostader aktiebolag
# 99985  administradora de consorcio rci brasil ltda
# 99986  vermogensparaplufonds   ipm european fundamental
# 99987  cmv spa
# 99988  vd sc sprl
# 99989  fruk holdings no1 limited
# 99990  cherry central cooperative  inc
# 99991  jj oxford  llc
# 99992  zannini   spa
# 99993  lumirama inc
# 99994  transamerica capital  inc
# 99995  pioneer   premium fond 2  pioneer investicni spolecnost  as  otevreny podilovy fond
# 99996  morningstar international shares high opportunities  hedged  fund
# 99997  benidur pensioen bv
# 99998  anwb bv
# 99999  grupo satocan sa
#
# [100000 rows x 9 columns]

# %%
print len(train)
print train.loc[train["company_id"]==train["rank1_id"]].shape
print train.loc[train["company_id"]!=train["rank1_id"]].shape
# Out:
# 100000
# (36403, 9)
# (63597, 9)

# %%
train_sub = train.loc[train["company_id"]!=-1]
print np.sum(train_sub["company_id"] == train_sub["rank1_id"])/float(len(train_sub))
# Out:
# 0.5219517091075935

# %% [markdown]
# ##### Accuracy = 0.5219
# * n_grams=[2,3]
# * dim =300
# * window =5
# * min_count=5
# * workers=4
# * num_trees_annoy=300
