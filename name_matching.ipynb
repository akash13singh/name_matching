# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import make_pipeline
from sklearn import svm, linear_model
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_curve, auc,f1_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from collections import defaultdict
import unicodedata
import random
random.seed(37)

# %%
pd.set_option('display.max_colwidth', -1)

# %%
path = "/home/akash/projects/data_analysis/ing/data/"

# %%
companies = pd.read_csv(path+"G.csv", delimiter="|")
train = pd.read_csv(path+"STrain.csv", delimiter="|")

# %%
companies.head()
# Out:
#    company_id                        name
# 0  634022      PRIMCOM SA
# 1  324497      The David Isaacs Fund
# 2  280848      Bramor Enterprises Limited
# 3  432662      NAVEXIM S.A.
# 4  524224      Magal Group SA

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450256 entries, 0 to 450255
# Data columns (total 2 columns):
# company_id    450256 non-null int64
# name          450256 non-null object
# dtypes: int64(1), object(1)
# memory usage: 6.9+ MB

# %%
train.head()
# Out:
#    train_index                                                          name  \
# 0  0            TRATTAMENTO Ltd RIFIUTI METROPOLITANI SPA  SIGLABILE TRM SPA
# 1  1            A IRL Fuund
# 2  2            BMR-500 Kendall LLC 1 Mezz GmbH
# 3  3            Solich GmbH KG
# 4  4            Drzyzzga Funds Logi. sp. z oo
#
#    company_id
# 0  177358
# 1  568472
# 2  195692
# 3 -1
# 4  404178

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
# train_index    100000 non-null int64
# name           100000 non-null object
# company_id     100000 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 2.3+ MB

# %%
test = pd.read_csv(path+"STest.csv", delimiter=",")
test.head()
# Out:
#    test_index                                        name
# 0  0           THEking'S ROYAL HUSSARS OFFI. TRUST' TRUST
# 1  1           Southern Powe rcompany SICAV
# 2  2           BMO S&P/TSX Ladde. Share ETF Index
# 3  3           PaI
# 4  4           Clearview Two

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 2 columns):
# test_index    100000 non-null int64
# name          99999 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
print train.columns
print test.columns
# Out:
# Index([u'train_index', u'name', u'company_id'], dtype='object')
# Index([u'test_index', u'name'], dtype='object')

# %%
print train.shape
print train["name"].nunique()
# Out:
# (100000, 3)
# 99365

# %%
print test.shape
print test["name"].nunique()
# Out:
# (100000, 2)
# 99323

# %%
print len(set(test["name"]) & set(train["name"]))
# Out:
# 1075

# %% [markdown]
# #### Sample Data

# %%
companies = companies.sample(50000)

# %%
train_0 = train.loc[train["company_id"]==-1]
print train_0.shape
train_1 = train.loc[train["company_id"]>=0]

print train_1.shape
# Out:
# (30256, 3)
# (69744, 3)

# %%
train = train_1.loc[train_1["company_id"].isin(companies["company_id"])]
print train.shape
# Out:
# (7828, 3)

# %%
companies = companies.reset_index(drop=True)
companies.head()
# Out:
#    company_id  \
# 0  397803
# 1  1036
# 2  545357
# 3  413401
# 4  142020
#
#                                                                                  name
# 0  Conforma NV
# 1  Morgan Stanley Investment Funds - Emerging Markets Fixed Income Opportunities Fund
# 2  Eurolease Group EAD
# 3  Merum Vastgoed Sittard B.V.
# 4  Coloramo Federal Credit Union

# %%
train0_sample = train_0.sample(int((1/9.0)*len(train_0)))
print len(train0_sample)
# Out:
# 3361

# %%
train = pd.concat([train,train0_sample])

# %%
train.shape
# Out:
# (11189, 3)

# %%
train = train.reset_index(drop=True)
train.head()
# Out:
#    train_index                          name  company_id
# 0  9            RBPA Leeuw                    526042
# 1  12           CP X, spol. s r.o.            139980
# 2  14           Dansk Socialrådgiverforening  179426
# 3  31           Central Milling Holdi ngs,    202295
# 4  36           GTA (LIMITED LLC              144245

# %% [markdown]
# #### Make map of company_ids to Annoy_index_ids

# %%
# annoy_ids are from 0 to len(company_ids) -1 
# annoy_ids are stored in list. List index are annoy_ids and the value is teh correspodnign company_id
# Company_ids are stored in a dict. The key is company id and the value is annoy_id
def build_company_annoy_maps(company_ids):
    annoy2company = []
    company2annoy = defaultdict(lambda:0)
    for c_id in company_ids:
        if c_id not in company2annoy:
            annoy2company.append(c_id)
            company2annoy[c_id] = len(annoy2company)-1
    return annoy2company, company2annoy

# %%
annoy2company, company2annoy = build_company_annoy_maps(companies["company_id"].values)

# %%
print len(annoy2company)
print len(company2annoy)
# Out:
# 50000
# 50000

# %%
import random
for i in range(5):
    annoy_id = random.randint(0,50000)
    assert annoy_id ==  company2annoy[annoy2company[annoy_id]]
    print annoy_id, annoy2company[annoy_id], company2annoy[annoy2company[annoy_id]]
# Out:
# 34100 241706 34100
# 4580 443259 4580
# 30891 306121 30891
# 42096 521034 42096
# 41728 639198 41728

# %%
def remove_accents(df,**kw_args):
    old_col =  kw_args["old_col"]
    new_col =  kw_args["new_col"]
    def remove_accents_inner(input_str):
        nfkd_form = unicodedata.normalize('NFKD', unicode(input_str, 'utf8'))
        return u"".join([c for c in nfkd_form if not unicodedata.combining(c)])
    
    df[new_col] = df[old_col].apply(remove_accents_inner)
    return df

def make_accent_transformer(old_col, new_col):
    return FunctionTransformer(remove_accents, validate=False,
                                         kw_args={"old_col":old_col,"new_col":new_col})

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/akash/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]|@,;\-\\\+#~!$%^]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z ]')
STOPWORDS = set(stopwords.words('english'))
#-#+_!`~\\

# %%
s = "for from india and add+g-ddc.b.g,c\g-hh ak|ash#sin/gh dee$pt^a su%d"
s=re.sub(REPLACE_BY_SPACE_RE," ",s)
s= re.sub(BAD_SYMBOLS_RE,"",s)
s= ' '.join(word for word in s.split() if word not in STOPWORDS)
print s
# Out:
# india add g ddcbg c g hh ak ash sin gh dee pt su

# %%
def clean_name(df,**kw_args):
    old_col =  kw_args["old_col"]
    new_col =  kw_args["new_col"]
    
    def regex_clean(text):
        text = re.sub(REPLACE_BY_SPACE_RE, " ", text)
        text = re.sub(BAD_SYMBOLS_RE, "", text)
        #text= ' '.join(word for word in text.split() if word not in STOPWORDS)
        return text
    
    df[new_col] = df[old_col].str.lower().str.strip()
    df[new_col] = df[old_col].apply(regex_clean)
    
    return df

def make_clean_name_transformer(old_col, new_col):
    return FunctionTransformer(clean_name, validate=False, kw_args={"old_col":old_col,"new_col":new_col})

# %%
name_pipeline = make_pipeline(make_accent_transformer("name", "clean_name"),
                                    make_clean_name_transformer("clean_name", "clean_name"))
companies = name_pipeline.transform(companies)

# %%
companies.sample(10)
# Out:
#        company_id                                           name  \
# 3569   83139       Hartley & Marks Publishers Inc.
# 16207  311669      Calico West Hartford LLC
# 34759  303768      Tresmontes Lucchetti S.A.
# 22619  387575      Shani Realty, LLC
# 45940  264764      BKS International World Wide Investments, Inc
# 39452  519410      LABORATORIO POLO SRL
# 16392  117171      Evolution M 7
# 33034  404318      Exklusiv Portfolio SICAV - Ertrag
# 39503  198263      PALATINE MONETAIRE
# 42731  514685      St Job Rotterdam C.V.
#
#                                           clean_name
# 3569   hartley  marks publishers inc
# 16207  calico west hartford llc
# 34759  tresmontes lucchetti sa
# 22619  shani realty  llc
# 45940  bks international world wide investments  inc
# 39452  laboratorio polo srl
# 16392  evolution m 7
# 33034  exklusiv portfolio sicav   ertrag
# 39503  palatine monetaire
# 42731  st job rotterdam cv

# %%
print companies.shape
print companies["clean_name"].nunique()
# Out:
# (50000, 3)
# 49955

# %%
train.head()
# Out:
#    train_index                          name  company_id
# 0  9            RBPA Leeuw                    526042
# 1  12           CP X, spol. s r.o.            139980
# 2  14           Dansk Socialrådgiverforening  179426
# 3  31           Central Milling Holdi ngs,    202295
# 4  36           GTA (LIMITED LLC              144245

# %%
print train.shape
train.sample(10)
# Out:
# (11189, 3)
#       train_index  \
# 8415  71832
# 5472  70023
# 3779  48227
# 5240  67054
# 4322  55481
# 1774  22182
# 7725  98793
# 9888  69241
# 7381  94716
# 7071  90756
#
#                                                                  name  \
# 8415  db x-trac. Global - Euro Stoxx 50® ex Financials UCITS ETF (DR)
# 5472  Fruktimporten Stock holm Capital AB
# 3779  HC mCL
# 5240  HK VODA BELAood Inter.
# 4322  Schoellerbank Euroalternativ
# 1774  KE Wiborg Holding Capital ApS
# 7725  Horizons EIEE
# 9888  SIgAV UEME LLC
# 7381  unctum Saliens BV
# 7071  442 Lorimer LsLC Street
#
#       company_id
# 8415 -1
# 5472  116782
# 3779  568979
# 5240  217936
# 4322  28329
# 1774  433285
# 7725  525424
# 9888 -1
# 7381  250026
# 7071  503772

# %%
from collections import Counter
count_vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 1), min_df=1)
# X matrix where the row represents sentences and column is our one-hot vector for each token in our vocabulary
X = count_vectorizer.fit_transform(companies["clean_name"])

# Vocabulary
vocab = list(count_vectorizer.get_feature_names())

# Column-wise sum of the X matrix.
# It's some crazy numpy syntax that looks horribly unpythonic
# For details, see http://stackoverflow.com/questions/3337301/numpy-matrix-to-array
# and http://stackoverflow.com/questions/13567345/how-to-calculate-the-sum-of-all-columns-of-a-2d-numpy-array-efficiently
counts = X.sum(axis=0).A1

freq_distribution = Counter(dict(zip(vocab, counts)))

# %%
print (freq_distribution.most_common(100))
# Out:
# [(u'llc', 4888), (u'fund', 4321), (u'limited', 3877), (u'gmbh', 3253), (u'inc', 2859), (u'srl', 2348), (u'bv', 2311), (u'trust', 2259), (u'ltd', 1759), (u'sa', 1622), (u'co', 1385), (u'lp', 1247), (u'global', 1239), (u'company', 1168), (u'the', 1164), (u'holding', 1113), (u'de', 1082), (u'kg', 1082), (u'funds', 1074), (u'ab', 1050), (u'investment', 988), (u'sl', 855), (u'international', 831), (u'capital', 813), (u'spa', 747), (u'of', 741), (u'di', 731), (u'holdings', 728), (u'equity', 725), (u'ii', 696), (u'group', 681), (u'as', 678), (u'sicav', 664), (u'investments', 625), (u'management', 612), (u'aps', 599), (u'societa', 573), (u'bond', 554), (u'portfolio', 539), (u'partners', 537), (u'invest', 512), (u'oy', 490), (u'bank', 488), (u'and', 466), (u'corporation', 443), (u'master', 441), (u'sro', 429), (u'income', 426), (u'plc', 421), (u'mbh', 415), (u'settlement', 398), (u'nv', 391), (u'europe', 391), (u'ag', 390), (u'beheer', 389), (u'spoka', 387), (u'services', 381), (u'etf', 365), (u'asset', 363), (u'series', 357), (u'und', 352), (u'credit', 349), (u'uk', 348), (u'fonds', 344), (u'in', 338), (u'us', 332), (u'street', 323), (u'sp', 323), (u'finance', 322), (u'energy', 321), (u'properties', 318), (u'sas', 316), (u'markets', 306), (u'snc', 303), (u'index', 299), (u'public', 292), (u'emerging', 286), (u'real', 285), (u'aktiebolag', 281), (u'pension', 275), (u'iii', 273), (u'growth', 269), (u'trading', 266), (u'multi', 264), (u'tarsasag', 262), (u'agricola', 257), (u'korlatolt', 254), (u'rl', 253), (u'felelossegu', 253), (u'van', 251), (u'partnership', 251), (u'pty', 247), (u'oo', 245), (u'gesellschaft', 241), (u'estate', 240), (u'property', 231), (u'life', 230), (u'la', 229), (u'opportunities', 229), (u'for', 228)]

# %%
train = name_pipeline.transform(train)

# %%
train.sample(10)
# Out:
#       train_index  \
# 1945  24251
# 7099  91063
# 7     78
# 2456  31140
# 4557  58359
# 5682  72686
# 3281  41585
# 1591  19831
# 3967  50757
# 7471  95807
#
#                                                                                    name  \
# 1945  Fack. GmbH + Co KG
# 7099  GUAPULO Funds TRUST
# 7     Limited Shevo
# 2456  HOLDINGSELSKABET AF 31. MARTS Holdings 2003 ApS
# 4557  IN, C. por SgICAV A.
# 5682  MELF S.à r.l.
# 3281  HE 6095, LP
# 1591  Believa GmbH
# 3967  HVP Ligting NV
# 7471  BANCA VALDICHIANA CREDITO COOPE RATIVO TOSCO Funds - UMBRO - SOCIETA' COOPERATIVA
#
#       company_id  \
# 1945  417042
# 7099  178505
# 7     102540
# 2456  180908
# 4557  179184
# 5682  212941
# 3281  323483
# 1591  458164
# 3967  398740
# 7471  349816
#
#                                                                             clean_name
# 1945  fack gmbh   co kg
# 7099  guapulo funds trust
# 7     limited shevo
# 2456  holdingselskabet af 31 marts holdings 2003 aps
# 4557  in  c por sgicav a
# 5682  melf sa rl
# 3281  he 6095  lp
# 1591  believa gmbh
# 3967  hvp ligting nv
# 7471  banca valdichiana credito coope rativo tosco funds   umbro   societa cooperativa

# %%
tfidf_vectorizer = TfidfVectorizer( max_df=0.8, ngram_range=(2,3), analyzer="char",
                                       token_pattern='(\S+)', )

# %%
company_vectors = tfidf_vectorizer.fit_transform(companies["clean_name"])

# %%
type(company_vectors)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
company_vectors.shape
# Out:
# (50000, 15215)

# %%
companies.shape
# Out:
# (50000, 3)

# %%
for i in range(5):
    print tfidf_vectorizer.inverse_transform(company_vectors[i])
    c_id = companies.iloc[i]["company_id"]
    print companies.iloc[i]["name"], c_id, company2annoy[c_id], annoy2company[company2annoy[c_id]]
    
    print "-"*20
# Out:
# [array([u'co', u'on', u'nf', u'fo', u'or', u'rm', u'ma', u'a ', u' n',
#        u'nv', u'con', u'onf', u'nfo', u'for', u'orm', u'rma', u'ma ',
#        u'a n', u' nv'], dtype='<U3')]
# Conforma NV 397803 0 397803
# --------------------
# [array([u'co', u'or', u'ma', u'nv', u'mo', u'rg', u'ga', u'an', u'n ',
#        u' s', u'st', u'ta', u'nl', u'le', u'ey', u'y ', u' i', u'in',
#        u've', u'es', u'tm', u'me', u'en', u'nt', u't ', u' f', u'fu',
#        u'un', u'nd', u'ds', u's ', u' e', u'em', u'er', u'gi', u'ng',
#        u'g ', u' m', u'ar', u'rk', u'ke', u'et', u'ts', u'fi', u'ix',
#        u'xe', u'ed', u'd ', u'nc', u'om', u'e ', u' o', u'op', u'pp',
#        u'po', u'rt', u'tu', u'ni', u'it', u'ti', u'ie', u'mor', u'org',
#        u'rga', u'gan', u'an ', u'n s', u' st', u'sta', u'tan', u'anl',
#        u'nle', u'ley', u'ey ', u'y i', u' in', u'inv', u'nve', u'ves',
#        u'est', u'stm', u'tme', u'men', u'ent', u'nt ', u't f', u' fu',
#        u'fun', u'und', u'nds', u'ds ', u's e', u' em', u'eme', u'mer',
#        u'erg', u'rgi', u'gin', u'ing', u'ng ', u'g m', u' ma', u'mar',
#        u'ark', u'rke', u'ket', u'ets', u'ts ', u's f', u' fi', u'fix',
#        u'ixe', u'xed', u'ed ', u'd i', u'inc', u'nco', u'com', u'ome',
#        u'me ', u'e o', u' op', u'opp', u'ppo', u'por', u'ort', u'rtu',
#        u'tun', u'uni', u'nit', u'iti', u'tie', u'ies', u'es '],
#       dtype='<U3')]
# Morgan Stanley Investment Funds - Emerging Markets Fixed Income Opportunities Fund 1036 1 1036
# --------------------
# [array([u'le', u' e', u'e ', u'eu', u'ur', u'ro', u'ol', u'ea', u'as',
#        u'se', u' g', u'gr', u'ou', u'up', u'p ', u'ad', u'eur', u'uro',
#        u'rol', u'ole', u'lea', u'eas', u'ase', u'se ', u'e g', u' gr',
#        u'gro', u'rou', u'oup', u'up ', u'p e', u' ea', u'ead'],
#       dtype='<U3')]
# Eurolease Group EAD 545357 2 545357
# --------------------
# [array([u' s', u'st', u'ta', u'me', u'er', u'ar', u'ed', u'd ', u'it',
#        u'mer', u'ed ', u'as', u'ru', u'um', u'm ', u' v', u'va', u'tg',
#        u'go', u'oe', u'si', u'tt', u'rd', u' b', u'bv', u'eru', u'rum',
#        u'um ', u'm v', u' va', u'vas', u'ast', u'stg', u'tgo', u'goe',
#        u'oed', u'd s', u' si', u'sit', u'itt', u'tta', u'tar', u'ard',
#        u'rd ', u'd b', u' bv'], dtype='<U3')]
# Merum Vastgoed Sittard B.V. 413401 3 413401
# --------------------
# [array([u'co', u'on', u'or', u'mo', u't ', u' f', u'un', u'er', u'ed',
#        u'ni', u'it', u'uni', u'ol', u'lo', u'ra', u'am', u'o ', u'fe',
#        u'de', u'al', u'l ', u' c', u'cr', u're', u'di', u' u', u'io',
#        u'col', u'olo', u'lor', u'ora', u'ram', u'amo', u'mo ', u'o f',
#        u' fe', u'fed', u'ede', u'der', u'era', u'ral', u'al ', u'l c',
#        u' cr', u'cre', u'red', u'edi', u'dit', u'it ', u't u', u' un',
#        u'nio', u'ion'], dtype='<U3')]
# Coloramo Federal Credit Union 142020 4 142020
# --------------------

# %%
companies.tail()
# Out:
#        company_id                                                name  \
# 49995  66919       R.C. Bigelow, Inc.
# 49996  487440      AMP Capital Infrastructure Debt Fund III (USD), LP
# 49997  316479      Real Torino, Inc.
# 49998  80413       GS Legacy Crossing, LLC
# 49999  399901      "NES 2005 S.R.L."
#
#                                                clean_name
# 49995  rc bigelow  inc
# 49996  amp capital infrastructure debt fund iii  usd   lp
# 49997  real torino  inc
# 49998  gs legacy crossing  llc
# 49999  nes 2005 srl

# %%
annoy2company[49999]
# Out:
# 399901

# %%
type(company_vectors[0].todense())
print np.squeeze(np.asarray(company_vectors[0].todense())).shape
# Out:
# (15215,)

# %%
from annoy import AnnoyIndex

index_size = len(tfidf_vectorizer.vocabulary_)
table = AnnoyIndex(index_size)

for i in range(company_vectors.shape[0]):
    if i%10000==0:
        print "indexed %s items"%i
    table.add_item(i,np.squeeze(np.asarray(company_vectors[i].todense())))
# Out:
# indexed 0 items
# indexed 10000 items
# indexed 20000 items
# indexed 30000 items
# indexed 40000 items

# %%
table.build(100)
# Out:
# True

# %%
table.save("annoy_index.ann")
# Out:
# True

# %%
table = AnnoyIndex(index_size)
table.load("annoy_index.ann")
# Out:
# True

# %% [markdown]
# #### Reteiveal

# %%
train = train.merge(companies, how="left", on="company_id", suffixes=('','_truth'))

# %%
train_vectors = tfidf_vectorizer.transform(train["clean_name"])

# %%
train_vectors_dense = np.squeeze(np.asarray(train_vectors.todense()))

# %%
train_vectors_dense.shape
# Out:
# (11189, 15215)

# %%
def get_nearest_neighbours(vectors, num_neighbours=5, search_nodes=-1, include_distances=True):
    neighbours = np.empty(shape=(len(vectors),num_neighbours), dtype=np.int32)
    distances = np.empty(shape=(len(vectors),num_neighbours))
#     print len(vectors)
#     print neighbours.shape
#     print distances.shape
    for idx,v in enumerate(vectors):
        annoy_ids, annoy_distances = table.get_nns_by_vector(v, n=num_neighbours, search_k=search_nodes, include_distances=include_distances)
        neighbours[idx,:] = annoy_ids
        distances[idx,:] = annoy_distances
    return neighbours, distances

# %%
neighbours, distances = get_nearest_neighbours(train_vectors_dense)

# %%
neighbours
# Out:
# array([[44764, 19848, 42571, 32042, 23728],
#        [33988, 31936, 39184, 33960, 17123],
#        [  583, 27741, 12374, 45411, 39815],
#        ...,
#        [21071, 10158, 13313, 10123, 13075],
#        [26232, 18286, 44991,  7696,  7870],
#        [  972, 18530, 29467, 31200,  8931]], dtype=int32)

# %%
neigbours =np.vectorize(lambda x: annoy2company[x])(neighbours)

# %%
rank_1 = neigbours[:,0]
rank_1
# Out:
# array([526042, 115370, 179426, ..., 641016,  77628, 255937])

# %%
train["rank1_id"] = rank_1

# %%
train= train.merge(companies[['company_id', 'clean_name']], left_on="rank1_id", 
                   right_on="company_id", suffixes=("","_rank1"))

# %%
train
# Out:
#        train_index  \
# 0      9
# 1      12
# 2      99957
# 3      14
# 4      31
# 5      12088
# 6      34591
# 7      36
# 8      53
# 9      71
# 10     42080
# 11     53448
# 12     78
# 13     98
# 14     101
# 15     109
# 16     88902
# 17     116
# 18     120
# 19     121
# 20     128
# 21     135
# 22     147
# 23     6433
# 24     167
# 25     206
# 26     248
# 27     260
# 28     275
# 29     329
# ...    ...
# 11159  87238
# 11160  64353
# 11161  51773
# 11162  76587
# 11163  10136
# 11164  7677
# 11165  28949
# 11166  43165
# 11167  20575
# 11168  34781
# 11169  99922
# 11170  46535
# 11171  64757
# 11172  90030
# 11173  27939
# 11174  79648
# 11175  57629
# 11176  65562
# 11177  64149
# 11178  79775
# 11179  22298
# 11180  62257
# 11181  80925
# 11182  45168
# 11183  6510
# 11184  16157
# 11185  12831
# 11186  69494
# 11187  82539
# 11188  71677
#
#                                                                                                  name  \
# 0      RBPA Leeuw
# 1      CP X, spol. s r.o.
# 2      ORTEX , spol. s ro
# 3      Dansk Socialrådgiverforening
# 4      Central Milling Holdi ngs,
# 5      Central Milling Holdings, Inc.
# 6      Central Milling Holdi., Inc Funds.
# 7      GTA (LIMITED LLC
# 8      Bamboo Holdings Ltd
# 9      HPB, LC
# 10     PB td.
# 11     PB 11
# 12     Limited Shevo
# 13     Gerritsgebr SICAV Trading B.V.
# 14     MSH Fund
# 15     Sociedad-IT de PSRL de Capital Holdings Variable
# 16     HSBC 6 DE FSAC VARI ABLE DE INVERSION DE RENTA VARI ABLE
# 17     AB Industricentralen Srandvägen
# 18     SSgA USD LLC Ultra Bond Fund
# 19     M3 Opportunitas SICAV
# 20     Brou ghton Petroleum, Inc
# 21     Helsingin Matkailusäätaö - Stiftelsen för Helsingfors Turism sr
# 22     Asset Exch ange Company Capital ICAV - AMX Capital– Trend Feeder – Spect.
# 23     Aset Management Exchange AMX - ICAV Trend Capital – Spectrum
# 24     EAGLE FUND
# 25     IMPRESA COLLE ONI GIACOMO & FIGLI - S.R.L.
# 26     SS Retir ement Communities I, LLC
# 27     Dewin Kunststoffen Investment BV
# 28     Wholesale Global Equity - Value Fund (Hedged)
# 29     SOPRA. STERIA
# ...              ...
# 11159  HI-KABL GmbH-Fonds
# 11160  Belle Epoque Mode et Accesoires SL
# 11161  CW Hardi. Beheer BV
# 11162  EUROS EMILLAS S.A.
# 11163  Dece.-Deforce NV
# 11164  Lodestar Trust KMNL BV
# 11165  Beresford EfMUs PLC - Indexed Fund Equity EfMU
# 11166  AAC
# 11167  CWA 3 B.V. & CO. KG.
# 11168  Aozora Trust Bank, Ltd. acting as trustee for Tokkin Trust Fund NO.23-22
# 11169  City of Bismarck Trust Park District
# 11170  EO Fachm. Co. KG
# 11171  866 UN Plaza Property LLC
# 11172  Erste Fiege Rweal GN Estate & Co. KG
# 11173  AllianzGI AWICO
# 11174  G&I IX 1225 Capital LLC
# 11175  MELAND KOMMUNE
# 11176  Hans und Maria yne Stiftung-Ewaldsen
# 11177  Life Technologies Limitedfinance
# 11178  Ashford Philadelphia Annex TRUST LP
# 11179  ALPHA REALestate SERVICES LLC Global
# 11180  BAI.
# 11181  PPC INVEST Investment INGATLANHASZNOSÍTÓ, KERESKEDELMI ÉS SZOLGÁLTATÓ KORLÁTOLT FELE. TÁRSASÁG
# 11182  Aviva Global Inves. ACS - AI Japan Equit yalpha Fund
# 11183  PA.PA.GIO. S.R.L.
# 11184  Quee. 34 LLC
# 11185  First Hawai ian Capital I
# 11186  Funds Public Limited CSHL Loan Opportunistic Portfolio
# 11187  Sancus Capital Blue Credit Opportunities Fund, Ltd.
# 11188  Senf Jacqnes Theaterpartners B.V.
#
#        company_id  \
# 0      526042
# 1      139980
# 2      115370
# 3      179426
# 4      202295
# 5      202295
# 6      202295
# 7      144245
# 8      130929
# 9      342136
# 10     490503
# 11     631015
# 12     102540
# 13     376828
# 14     192096
# 15     233811
# 16    -1
# 17     407644
# 18     33896
# 19     561141
# 20     237393
# 21     134572
# 22     9527
# 23    -1
# 24     424502
# 25     285043
# 26     455711
# 27     432365
# 28     154239
# 29     378164
# ...       ...
# 11159 -1
# 11160 -1
# 11161 -1
# 11162 -1
# 11163 -1
# 11164 -1
# 11165 -1
# 11166 -1
# 11167 -1
# 11168 -1
# 11169 -1
# 11170 -1
# 11171 -1
# 11172 -1
# 11173 -1
# 11174 -1
# 11175 -1
# 11176 -1
# 11177 -1
# 11178 -1
# 11179 -1
# 11180 -1
# 11181 -1
# 11182 -1
# 11183 -1
# 11184 -1
# 11185 -1
# 11186 -1
# 11187 -1
# 11188 -1
#
#                                                                                           clean_name  \
# 0      rbpa leeuw
# 1      cp x  spol s ro
# 2      ortex   spol s ro
# 3      dansk socialradgiverforening
# 4      central milling holdi ngs
# 5      central milling holdings  inc
# 6      central milling holdi  inc funds
# 7      gta  limited llc
# 8      bamboo holdings ltd
# 9      hpb  lc
# 10     pb td
# 11     pb 11
# 12     limited shevo
# 13     gerritsgebr sicav trading bv
# 14     msh fund
# 15     sociedad it de psrl de capital holdings variable
# 16     hsbc 6 de fsac vari able de inversion de renta vari able
# 17     ab industricentralen srandvagen
# 18     ssga usd llc ultra bond fund
# 19     m3 opportunitas sicav
# 20     brou ghton petroleum  inc
# 21     helsingin matkailusaatao   stiftelsen for helsingfors turism sr
# 22     asset exch ange company capital icav   amx capital trend feeder  spect
# 23     aset management exchange amx   icav trend capital  spectrum
# 24     eagle fund
# 25     impresa colle oni giacomo  figli   srl
# 26     ss retir ement communities i  llc
# 27     dewin kunststoffen investment bv
# 28     wholesale global equity   value fund  hedged
# 29     sopra steria
# ...             ...
# 11159  hi kabl gmbh fonds
# 11160  belle epoque mode et accesoires sl
# 11161  cw hardi beheer bv
# 11162  euros emillas sa
# 11163  dece deforce nv
# 11164  lodestar trust kmnl bv
# 11165  beresford efmus plc   indexed fund equity efmu
# 11166  aac
# 11167  cwa 3 bv  co kg
# 11168  aozora trust bank  ltd acting as trustee for tokkin trust fund no23 22
# 11169  city of bismarck trust park district
# 11170  eo fachm co kg
# 11171  866 un plaza property llc
# 11172  erste fiege rweal gn estate  co kg
# 11173  allianzgi awico
# 11174  gi ix 1225 capital llc
# 11175  meland kommune
# 11176  hans und maria yne stiftung ewaldsen
# 11177  life technologies limitedfinance
# 11178  ashford philadelphia annex trust lp
# 11179  alpha realestate services llc global
# 11180  bai
# 11181  ppc invest investment ingatlanhasznosito  kereskedelmi es szolgaltato korlatolt fele tarsasag
# 11182  aviva global inves acs   ai japan equit yalpha fund
# 11183  papagio srl
# 11184  quee 34 llc
# 11185  first hawai ian capital i
# 11186  funds public limited cshl loan opportunistic portfolio
# 11187  sancus capital blue credit opportunities fund  ltd
# 11188  senf jacqnes theaterpartners bv
#
#                                                                                   name_truth  \
# 0      RBPA Leeuw
# 1      CTP Property X, spol. s r.o.
# 2      ORTEX , spol. s r.o.
# 3      Dansk Socialrådgiverforening
# 4      Central Milling Holdings, Inc.
# 5      Central Milling Holdings, Inc.
# 6      Central Milling Holdings, Inc.
# 7      GTA (RETAIL) LIMITED
# 8      Bamboo Investment Holdings Ltd
# 9      HPB Investments, LLC
# 10     Pathlight BGC Ltd.
# 11     PB 11
# 12     Shevo Trading Limited
# 13     Gebr. Gerrits Trading B.V.
# 14     Stiftung Mainzer Herz
# 15     Hewlett-Packard IT Services, Sociedad de Responsabilidad Limitada de Capital Variable
# 16     NaN
# 17     AB Industricentralen Strandvägen
# 18     SSgA USD Ultra Short Bond Fund
# 19     M3 Opportunitas
# 20     Broughton Petroleum, Inc
# 21     Helsingin Matkailusäätiö - Stiftelsen för Helsingfors Turism sr
# 22     Asset Management Exchange Feeder ICAV - AMX Feeder– Trend Capital – Spectrum
# 23     NaN
# 24     EAGLE FUND
# 25     IMPRESA COLLEONI GIACOMO & FIGLI - S.R.L.
# 26     Santee Senior Retirement Communities I, LLC
# 27     Dewin Kunststoffen B.V.
# 28     Wholesale Global Equity - Value Fund (Hedged)
# 29     SOPRA STERIA GROUP
# ...                   ...
# 11159  NaN
# 11160  NaN
# 11161  NaN
# 11162  NaN
# 11163  NaN
# 11164  NaN
# 11165  NaN
# 11166  NaN
# 11167  NaN
# 11168  NaN
# 11169  NaN
# 11170  NaN
# 11171  NaN
# 11172  NaN
# 11173  NaN
# 11174  NaN
# 11175  NaN
# 11176  NaN
# 11177  NaN
# 11178  NaN
# 11179  NaN
# 11180  NaN
# 11181  NaN
# 11182  NaN
# 11183  NaN
# 11184  NaN
# 11185  NaN
# 11186  NaN
# 11187  NaN
# 11188  NaN
#
#                                                                             clean_name_truth  \
# 0      rbpa leeuw
# 1      ctp property x  spol s ro
# 2      ortex   spol s ro
# 3      dansk socialradgiverforening
# 4      central milling holdings  inc
# 5      central milling holdings  inc
# 6      central milling holdings  inc
# 7      gta  retail  limited
# 8      bamboo investment holdings ltd
# 9      hpb investments  llc
# 10     pathlight bgc ltd
# 11     pb 11
# 12     shevo trading limited
# 13     gebr gerrits trading bv
# 14     stiftung mainzer herz
# 15     hewlett packard it services  sociedad de responsabilidad limitada de capital variable
# 16     NaN
# 17     ab industricentralen strandvagen
# 18     ssga usd ultra short bond fund
# 19     m3 opportunitas
# 20     broughton petroleum  inc
# 21     helsingin matkailusaatio   stiftelsen for helsingfors turism sr
# 22     asset management exchange feeder icav   amx feeder trend capital  spectrum
# 23     NaN
# 24     eagle fund
# 25     impresa colleoni giacomo  figli   srl
# 26     santee senior retirement communities i  llc
# 27     dewin kunststoffen bv
# 28     wholesale global equity   value fund  hedged
# 29     sopra steria group
# ...                   ...
# 11159  NaN
# 11160  NaN
# 11161  NaN
# 11162  NaN
# 11163  NaN
# 11164  NaN
# 11165  NaN
# 11166  NaN
# 11167  NaN
# 11168  NaN
# 11169  NaN
# 11170  NaN
# 11171  NaN
# 11172  NaN
# 11173  NaN
# 11174  NaN
# 11175  NaN
# 11176  NaN
# 11177  NaN
# 11178  NaN
# 11179  NaN
# 11180  NaN
# 11181  NaN
# 11182  NaN
# 11183  NaN
# 11184  NaN
# 11185  NaN
# 11186  NaN
# 11187  NaN
# 11188  NaN
#
#        rank1_id  company_id_rank1  \
# 0      526042    526042
# 1      115370    115370
# 2      115370    115370
# 3      179426    179426
# 4      202295    202295
# 5      202295    202295
# 6      202295    202295
# 7      144245    144245
# 8      130929    130929
# 9      631015    631015
# 10     631015    631015
# 11     631015    631015
# 12     102540    102540
# 13     376828    376828
# 14     196303    196303
# 15     169704    169704
# 16     169704    169704
# 17     407644    407644
# 18     33896     33896
# 19     561141    561141
# 20     237393    237393
# 21     134572    134572
# 22     9527      9527
# 23     9527      9527
# 24     424502    424502
# 25     285043    285043
# 26     455711    455711
# 27     432365    432365
# 28     154239    154239
# 29     378164    378164
# ...       ...       ...
# 11159  198475    198475
# 11160  283642    283642
# 11161  629217    629217
# 11162  37977     37977
# 11163  500117    500117
# 11164  66987     66987
# 11165  421657    421657
# 11166  379304    379304
# 11167  493484    493484
# 11168  65279     65279
# 11169  214303    214303
# 11170  480079    480079
# 11171  328123    328123
# 11172  408299    408299
# 11173  7869      7869
# 11174  573007    573007
# 11175  145359    145359
# 11176  413632    413632
# 11177  25492     25492
# 11178  430845    430845
# 11179  314471    314471
# 11180  482879    482879
# 11181  355851    355851
# 11182  343859    343859
# 11183  116870    116870
# 11184  518903    518903
# 11185  363583    363583
# 11186  170511    170511
# 11187  641016    641016
# 11188  255937    255937
#
#                                                                                            clean_name_rank1
# 0      rbpa leeuw
# 1      ortex   spol s ro
# 2      ortex   spol s ro
# 3      dansk socialradgiverforening
# 4      central milling holdings  inc
# 5      central milling holdings  inc
# 6      central milling holdings  inc
# 7      gta  retail  limited
# 8      bamboo investment holdings ltd
# 9      pb 11
# 10     pb 11
# 11     pb 11
# 12     shevo trading limited
# 13     gebr gerrits trading bv
# 14     tyndall cash fund
# 15     torrenova de inversiones sociedad de inversion de capital variable sa
# 16     torrenova de inversiones sociedad de inversion de capital variable sa
# 17     ab industricentralen strandvagen
# 18     ssga usd ultra short bond fund
# 19     m3 opportunitas
# 20     broughton petroleum  inc
# 21     helsingin matkailusaatio   stiftelsen for helsingfors turism sr
# 22     asset management exchange feeder icav   amx feeder trend capital  spectrum
# 23     asset management exchange feeder icav   amx feeder trend capital  spectrum
# 24     eagle fund
# 25     impresa colleoni giacomo  figli   srl
# 26     santee senior retirement communities i  llc
# 27     dewin kunststoffen bv
# 28     wholesale global equity   value fund  hedged
# 29     sopra steria group
# ...                   ...
# 11159  hbl gmbh  co kg
# 11160  modana accessories bv
# 11161  verdi beheer bv
# 11162  atlas europe limited
# 11163  force iroise
# 11164  polar star realty trust inc
# 11165  beresford funds plc   indexed global equity fund
# 11166  baacolla bv
# 11167  jamm 3 bv
# 11168  aozora trust bank  ltd acting as trustee for the tokkin trust fund no23 20
# 11169  vestry of st patricks parish
# 11170  schmidt gmbh  co kg
# 11171  coles property llc
# 11172  art invest real estate gmbh  co kg
# 11173  allianzgi fonds fam
# 11174  pomona capital ix  lp
# 11175  stord kommune
# 11176  stiftung enders
# 11177  esi technologies limited
# 11178  philadelphia hotel  llc
# 11179  alpha real estate services srl
# 11180  grubail
# 11181  profit m ingatlanhasznosito  uzletviteli  kereskedelmi es szolgaltato korlatolt felelossegu tarsasag
# 11182  aviva investors funds acs   ai japan equity fund
# 11183  gio steel srl
# 11184  34 main street llc
# 11185  first capital spa
# 11186  openworld public limited company   global opportunistic listed property fund
# 11187  pennant credit opportunities fund  lp
# 11188  hanover theater partners lp
#
# [11189 rows x 9 columns]

# %%
train.loc[train["company_id"]==train["rank1_id"]].shape
# Out:
# (6053, 9)

# %%
train_sub = train.loc[train["company_id"]!=-1]

# %%
print np.sum(train_sub["company_id"] == train_sub["rank1_id"])/float(len(train_sub))
# Out:
# 0.7732498722534492
